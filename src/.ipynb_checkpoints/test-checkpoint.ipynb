# %%
# -*- coding: utf-8 -*-
"""
Delish Webscraper Version1.
"""
import csv
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import re
import requests
import pandas as pd
import datetime
from functools import partial
#get current time
now = datetime.datetime.now()   
    
def parse_string(string_):
    string_ = string_.replace('\t', '').replace("  ", "").replace('\n', "")
    return string_
def parse_list(string_list):
    #create a list of the Items captured by the Beautiful Soup.get_text removes the tages but not the formating,
    # so the replace functions are taking out \t, \n, \xa0 formating
    new_list=[item.get_text().replace('\t', '').replace("  ", "").replace('\n', "").replace('\xa0',"") for item in string_list]
    return new_list
def get_data_allrecipes(url_string):
    try:
        uClient = uReq(url_string)
        page_html = uClient.read()
        uClient.close()
    #html parsing
        page_soup = soup(page_html ,"html.parser")
    #url
        url = url_string
        print(url)
    #title
        title= page_soup.find('h1').get_text()
        print(title)
        prep_time = page_soup.find('span', {'class':'prep-time-amount'}).get_text()
        prep_time = parse_string(prep_time)
        print(prep_time)
    #time
        total_time = page_soup.find('span', {'class':"total-time-amount"}).get_text()
        total_time = parse_string(total_time)
        print(total_time)
        #ingredients
        ingredient_amount = page_soup.findAll('span',{'class':'ingredient-amount'})
        ingredient_amount_list = parse_list(ingredient_amount)
        #print(ingredient_amount_list)
        ingredients = page_soup.findAll('span',{'class':'ingredient-description'})
        ingredient_list =parse_list(ingredients)
        ingredients_ = [str(m)+n for m,n in zip(ingredient_amount_list,ingredient_list)] 
        print(ingredients_)
    #instructions
        instructions = page_soup.findAll('div',{'class':"direction-lists"})
        instruction_list = parse_list(instructions)
        print(instruction_list)
        scraperdata= url, title, prep_time, total_time, ingredients_,instruction_list
        return scraperdata
    except Exception:
        pass

# %%
import csv
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import re
import requests
import pandas as pd
import datetime
proteins= ["beef", "chicken", "shrimp", "lentils"]
website_string = "http://www.delish.com/search/"
appended_lists=[]
'''
file_name = now.isoformat()+".csv"
file_name = file_name.replace(":", "_")
with open(file_name, "w",newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow("URL", "Title", "Prep Time", "Total Time", "Ingredients","Instructions")
        '''
columns = "URL", "Title", "Prep Time", "Total Time", "Ingredients","Instructions"
for protein in proteins:
    search_string= website_string+protein
    website_page = uReq(search_string)
    page_soup = soup(website_page, "html.parser")
    for link in page_soup.findAll('a', href=re.compile("/cooking/recipe-ideas")):
        url_string = website_string+link['href']
        scraper_content_list = get_data_allrecipes(url_string)
        appended_lists.append(scraper_content_list)
            #writer.writerow([scraper_content_list])
L = appended_lists
recipes = [x for x in L if x is None ]
# Out:
# http://www.delish.com/search//cooking/recipe-ideas/a23515497/easy-beef-stew-recipe/
# Beef Stew
# 0hours15mins
# 1hour25mins
# ['1 tbsp.vegetable oil', '2 lb.beef chuck stew meat, cubed into 1" pieces', '1 tbsp.extra-virgin olive oil', '1 onion, chopped', '2 carrots, peeled and cut into rounds', '2 stalks celery, chopped', '3 Kosher salt', ' 1/4c.Freshly ground black pepper', '6 c.cloves garlic, minced', '1 c.tomato paste', '1 tbsp.low-sodium beef broth', '1 tsp.red wine', '2 Worcestershire sauce', '1 lb.dried thyme', '1 c.bay leaves', ' 1/4c.baby potatoes, halved']
# ['Add onion, carrots, celery and potatoes to bowl of your crock pot. Place corned beef on top and season generously with salt, pepper, and pickling spices. Scatter thyme and bay leaves over meat and fill slow cooker bowl with water until it is almost completely covering the meat.Cook on high for 4 to 4 1/2 hours, until meat is tender. Add cabbage to crock pot and cook on high for 45 minutes to 1 hour more until cabbage is tender and cooked through. Remove meat and vegetables from slow cooker, slice and serve.']
# http://www.delish.com/search//cooking/recipe-ideas/a57965/slow-cooker-corned-beef-and-cabbage-recipe/
# Slow Cooker Corned Beef & Cabbage
# 0hours30mins
# 6hours0mins
# ['1 medium yellow onion, cut into large wedges', '3 large carrots, cut into thirds', '2 stalks celery, cut into thirds', ' 1/2lb.baby potatoes, halved', '1 corned beef brisket (2-3 lbs)', '1 kosher salt', '3 Freshly ground black pepper', '2 packed pickling spice', ' 1/2sprigs thyme']
# ['Add onion, carrots, celery and potatoes to bowl of your crock pot. Place corned beef on top and season generously with salt, pepper, and pickling spices. Scatter thyme and bay leaves over meat and fill slow cooker bowl with water until it is almost completely covering the meat.Cook on high for 4 to 4 1/2 hours, until meat is tender. Add cabbage to crock pot and cook on high for 45 minutes to 1 hour more until cabbage is tender and cooked through. Remove meat and vegetables from slow cooker, slice and serve.']
# http://www.delish.com/search//cooking/recipe-ideas/a26258692/irish-stew-recipe/
# Irish Beef Stew
# 0hours15mins
# 1hour10mins
# ['3 tbsp.extra-virgin olive oil, divided', '2 lb.beef chuck stew meat, cubed into 1" pieces', '1 Kosher salt', '2 Freshly ground black pepper', '2 onion, chopped', '3 medium carrots, peeled and cut into rounds', '3 stalks celery, chopped', '4 c.cloves garlic, minced', '1 medium russet potatoes, peeled and cut into large chunks', '2 tsp.low-sodium beef broth']
# ['In a large Dutch oven over medium heat, heat 2 tablespoons oil. Season beef with salt and pepper, then add to pot and cook on all sides until seared, 10 minutes, working in batches if necessary. Transfer beef to a plate.In same pot, add remaining tablespoon oil and cook onion, carrots, and celery until soft, 5 minutes. Season with salt and pepper. Add garlic and cook until fragrant, 1 minute.Add beef back to Dutch oven, then add potatoes, broth, beer, and thyme. Bring to a boil, then reduce heat to a simmer. Season with salt and pepper. Cover and let simmer until beef and potatoes are tender, 30 minutes.Garnish with parsley before serving.']
# http://www.delish.com/search//cooking/recipe-ideas/a26258692/irish-stew-recipe/
# Irish Beef Stew
# 0hours15mins
# 1hour10mins
# ['3 tbsp.extra-virgin olive oil, divided', '2 lb.beef chuck stew meat, cubed into 1" pieces', '1 Kosher salt', '2 Freshly ground black pepper', '2 onion, chopped', '3 medium carrots, peeled and cut into rounds', '3 stalks celery, chopped', '4 c.cloves garlic, minced', '1 medium russet potatoes, peeled and cut into large chunks', '2 tsp.low-sodium beef broth']
# ['In a large Dutch oven over medium heat, heat 2 tablespoons oil. Season beef with salt and pepper, then add to pot and cook on all sides until seared, 10 minutes, working in batches if necessary. Transfer beef to a plate.In same pot, add remaining tablespoon oil and cook onion, carrots, and celery until soft, 5 minutes. Season with salt and pepper. Add garlic and cook until fragrant, 1 minute.Add beef back to Dutch oven, then add potatoes, broth, beer, and thyme. Bring to a boil, then reduce heat to a simmer. Season with salt and pepper. Cover and let simmer until beef and potatoes are tender, 30 minutes.Garnish with parsley before serving.']
# http://www.delish.com/search//cooking/recipe-ideas/a26243431/instant-pot-corned-beef-recipe/
# Instant Pot Corned Beef
# 0hours15mins
# 2hours45mins
# ['1 large onion, cut into wedges', '1 (2-lb.) corned beef brisket, with seasoning packet', '4 c.low-sodium chicken broth', '1 small head cabbage, core removed and cut into wedges', '1 lb.baby potatoes, halved', '4 medium carrots, sliced and cut on the bias', '3 tbsp.extra-vigin olive oil']
# [" Place onion in bottom of a 6-quart Instant Pot. Place brisket on top and add seasoning packet. Pour in broth and seal lid. Set to pressure cook on high for 90 minutes.Follow manufacturer's guide for quick release, then remove corned beef and onions from Instant Pot. Keep remaining cooking liquid inside Instant Pot. Cover beef and keep warm.Add cabbage, potatoes, carrots, and oil to Instant Pot. Season with salt and pepper, then seal lid. Set to pressure cook on high for 4 minutes.Follow manufacturer's guide for quick release, then remove lid and serve vegetables with corned beef. Garnish with parsley and spoon additional cooking liquid over beef, if desired."]
# http://www.delish.com/search//cooking/recipe-ideas/a26243431/instant-pot-corned-beef-recipe/
# Instant Pot Corned Beef
# 0hours15mins
# 2hours45mins
# ['1 large onion, cut into wedges', '1 (2-lb.) corned beef brisket, with seasoning packet', '4 c.low-sodium chicken broth', '1 small head cabbage, core removed and cut into wedges', '1 lb.baby potatoes, halved', '4 medium carrots, sliced and cut on the bias', '3 tbsp.extra-vigin olive oil']
# [" Place onion in bottom of a 6-quart Instant Pot. Place brisket on top and add seasoning packet. Pour in broth and seal lid. Set to pressure cook on high for 90 minutes.Follow manufacturer's guide for quick release, then remove corned beef and onions from Instant Pot. Keep remaining cooking liquid inside Instant Pot. Cover beef and keep warm.Add cabbage, potatoes, carrots, and oil to Instant Pot. Season with salt and pepper, then seal lid. Set to pressure cook on high for 4 minutes.Follow manufacturer's guide for quick release, then remove lid and serve vegetables with corned beef. Garnish with parsley and spoon additional cooking liquid over beef, if desired."]
# http://www.delish.com/search//cooking/recipe-ideas/a26311211/corned-beef-hash-and-eggs-recipe/
# Corned Beef Hash and Eggs
# 0hours20mins
# 0hours55mins
# ['3 tbsp.extra-virgin olive oil', '1 onion, chopped', '1 bell pepper, chopped', '3 large russet potatoes, cubed', '1 tsp.dried oregano', '1 c.Kosher salt', '6 Freshly ground black pepper']
# ['Preheat oven to 400°. In a large ovenproof skillet over medium heat, heat oil. Add onion and bell pepper and cook until softened, 5 minutes, then add potatoes, oregano, salt and pepper.Cook until potatoes are golden and easily pierced with a fork, another 15 to 20 minutes. Add corned beef and cook until crispy, 5 minutes.Make 6 wells in hash, then crack an egg into each well. Season the eggs with salt and pepper.Transfer skillet to oven and bake until whites are just set, 8 minutes.']
# http://www.delish.com/search//cooking/recipe-ideas/a26311211/corned-beef-hash-and-eggs-recipe/
# Corned Beef Hash and Eggs
# 0hours20mins
# 0hours55mins
# ['3 tbsp.extra-virgin olive oil', '1 onion, chopped', '1 bell pepper, chopped', '3 large russet potatoes, cubed', '1 tsp.dried oregano', '1 c.Kosher salt', '6 Freshly ground black pepper']
# ['Preheat oven to 400°. In a large ovenproof skillet over medium heat, heat oil. Add onion and bell pepper and cook until softened, 5 minutes, then add potatoes, oregano, salt and pepper.Cook until potatoes are golden and easily pierced with a fork, another 15 to 20 minutes. Add corned beef and cook until crispy, 5 minutes.Make 6 wells in hash, then crack an egg into each well. Season the eggs with salt and pepper.Transfer skillet to oven and bake until whites are just set, 8 minutes.']
# http://www.delish.com/search//cooking/recipe-ideas/a58253/best-homemade-chili-recipe/
# Best-Ever Beef Chili
# 0hours10mins
# 0hours40mins
# ['1 tbsp.extra-virgin olive oil', ' 1/2large whiteonion, chopped', '3 cloves garlic, minced', '2 tbsp.tomato paste', '1 1/2lb.ground beef', '1 1/2tbsp.chili powder', '1 tsp.ground cumin', '1 tsp.dried oregano', ' 1/2tsp.paprika', ' 1/4tsp.cayenne pepper (optional)', '1 Kosher salt', '1 Freshly ground black pepper']
# ['In a large pot over medium heat, heat oil. Add onion and cook until soft, about 5 minutes. Stir in garlic and cook until fragrant, about 1 minute more, then add tomato paste, stirring to combine. Add ground beef and cook until no longer pink. Drain fat and return to heat. Add chili powder, cumin, oregano, paprika, cayenne (if using), and season generouslywith salt and pepper. Pour in kidney beans and crushed tomatoes and bring chili to a boil. Reduceheat and simmer20 minutes. Season with more salt and pepper, if necessary.Ladle into bowls and topwith cheddar, sour cream, and green onions. ']
# http://www.delish.com/search//cooking/recipe-ideas/a58253/best-homemade-chili-recipe/
# Best-Ever Beef Chili
# 0hours10mins
# 0hours40mins
# ['1 tbsp.extra-virgin olive oil', ' 1/2large whiteonion, chopped', '3 cloves garlic, minced', '2 tbsp.tomato paste', '1 1/2lb.ground beef', '1 1/2tbsp.chili powder', '1 tsp.ground cumin', '1 tsp.dried oregano', ' 1/2tsp.paprika', ' 1/4tsp.cayenne pepper (optional)', '1 Kosher salt', '1 Freshly ground black pepper']
# ['In a large pot over medium heat, heat oil. Add onion and cook until soft, about 5 minutes. Stir in garlic and cook until fragrant, about 1 minute more, then add tomato paste, stirring to combine. Add ground beef and cook until no longer pink. Drain fat and return to heat. Add chili powder, cumin, oregano, paprika, cayenne (if using), and season generouslywith salt and pepper. Pour in kidney beans and crushed tomatoes and bring chili to a boil. Reduceheat and simmer20 minutes. Season with more salt and pepper, if necessary.Ladle into bowls and topwith cheddar, sour cream, and green onions. ']
# http://www.delish.com/search//cooking/recipe-ideas/a26730042/reuben-crescent-roll-ups-recipe/
# Reuben Crescent Roll-Ups
# 0hours10mins
# 0hours45mins
# ['1 tube Crescent Rolls', '1 c.shredded Swiss cheese', ' 1/4lb.corned beef, thinly sliced', '1 c.sauerkraut', '2 tbsp.melted butter', ' 1/4c.Kosher salt', '1 tbsp.Freshly ground black pepper', '1 tbsp.mayonnaise', '1 tsp.ketchup']
# ['Preheat oven to 350°. Line a large baking sheet with parchment paper.Separate crescent dough into triangles. Top each triangle with an even layer of cheese, corned beef, and sauerkraut. Roll each triangle up, starting from the widest end. Place on prepared baking sheet and brush with butter. Season each roll-up with salt and pepper and bake until golden and cooked through, 20 to 25 minutes.Meanwhile, make Russian dressing: In a medium bowl, whisk together mayo, ketchup, horseradish, and Worcestershire sauce. Season with salt and pepper.Serve roll-ups hot with dressing on the side for dipping.']
# http://www.delish.com/search//cooking/recipe-ideas/a26730042/reuben-crescent-roll-ups-recipe/
# Reuben Crescent Roll-Ups
# 0hours10mins
# 0hours45mins
# ['1 tube Crescent Rolls', '1 c.shredded Swiss cheese', ' 1/4lb.corned beef, thinly sliced', '1 c.sauerkraut', '2 tbsp.melted butter', ' 1/4c.Kosher salt', '1 tbsp.Freshly ground black pepper', '1 tbsp.mayonnaise', '1 tsp.ketchup']
# ['Preheat oven to 350°. Line a large baking sheet with parchment paper.Separate crescent dough into triangles. Top each triangle with an even layer of cheese, corned beef, and sauerkraut. Roll each triangle up, starting from the widest end. Place on prepared baking sheet and brush with butter. Season each roll-up with salt and pepper and bake until golden and cooked through, 20 to 25 minutes.Meanwhile, make Russian dressing: In a medium bowl, whisk together mayo, ketchup, horseradish, and Worcestershire sauce. Season with salt and pepper.Serve roll-ups hot with dressing on the side for dipping.']
# http://www.delish.com/search//cooking/recipe-ideas/a23481075/stuffed-cabbage-rolls/
# Stuffed Cabbage
# 0hours25mins
# 2hours20mins
# ['2 tbsp.extra-virgin olive oil', ' 1/2large onion, chopped', '3 cloves garlic, minced', '2 tbsp.tomato paste', '1 (28-oz.) can crushed tomatoes', '2 tbsp.balsamic vinegar', '1 tbsp.brown sugar', '2 tsp.dried oregano', '15 Kosher salt', '1 lb.Freshly ground black pepper', ' 1/4c.cabbage leaves', ' 1/4c.ground beef', ' 1/2uncooked white rice', '2 tbsp.Italian bread crumbs']
# ['Preheat oven to 350°. In a large deep skillet (or large pot) over medium heat, heat oil. Add onion and cook until soft, 5 minutes. Stir in tomato paste and garlic and cook until fragrant, 1 minute. Pour over tomatoes then add vinegar, sugar, and oregano.Lower heat to medium-low and simmer for 20 minutes. Season with salt and pepper.', 'In a large pot of boiling water, blanch cabbage leaves until tender and flexible, about 1 minute. Set aside.Make filling: In a large bowl, combine ground meats, 1 cup sauce, rice, bread crumbs, onion, and parsley. Season with salt and pepper.Spread a thin layer of sauce on the bottom of a large baking dish.Using a paring knife, cut out the hard triangular rib from each cabbage leaf. Place about ⅓ cup filling into one end of each leaf, then roll up, tucking in the sides as you roll. Place rolls seam side-down on top of sauce in baking dish. Spoon remaining sauce on top of cabbage rolls then cover dish with foil. Bake 1 hour 15 minutes, until rice and meat are cooked through.Garnish with more parsley before serving.']
# http://www.delish.com/search//cooking/recipe-ideas/a23481075/stuffed-cabbage-rolls/
# Stuffed Cabbage
# 0hours25mins
# 2hours20mins
# ['2 tbsp.extra-virgin olive oil', ' 1/2large onion, chopped', '3 cloves garlic, minced', '2 tbsp.tomato paste', '1 (28-oz.) can crushed tomatoes', '2 tbsp.balsamic vinegar', '1 tbsp.brown sugar', '2 tsp.dried oregano', '15 Kosher salt', '1 lb.Freshly ground black pepper', ' 1/4c.cabbage leaves', ' 1/4c.ground beef', ' 1/2uncooked white rice', '2 tbsp.Italian bread crumbs']
# ['Preheat oven to 350°. In a large deep skillet (or large pot) over medium heat, heat oil. Add onion and cook until soft, 5 minutes. Stir in tomato paste and garlic and cook until fragrant, 1 minute. Pour over tomatoes then add vinegar, sugar, and oregano.Lower heat to medium-low and simmer for 20 minutes. Season with salt and pepper.', 'In a large pot of boiling water, blanch cabbage leaves until tender and flexible, about 1 minute. Set aside.Make filling: In a large bowl, combine ground meats, 1 cup sauce, rice, bread crumbs, onion, and parsley. Season with salt and pepper.Spread a thin layer of sauce on the bottom of a large baking dish.Using a paring knife, cut out the hard triangular rib from each cabbage leaf. Place about ⅓ cup filling into one end of each leaf, then roll up, tucking in the sides as you roll. Place rolls seam side-down on top of sauce in baking dish. Spoon remaining sauce on top of cabbage rolls then cover dish with foil. Bake 1 hour 15 minutes, until rice and meat are cooked through.Garnish with more parsley before serving.']
# http://www.delish.com/search//cooking/recipe-ideas/a44538/bacon-cheeseburger-dip-recipe/
# Bacon Cheeseburger Dip
# 0hours25mins
# 0hours40mins
# ['1 tbsp.extra-virgin olive oil', '1 large onion, chopped', ' 1/2lb.ground beef', '6 slices bacon', '8 oz.cream cheese, softened', ' 3/4c.shredded cheddar', ' 3/4c.shredded Monterey jack', '1 tbsp.Worcestershire sauce', '1 tsp.garlic powder']
# ['Preheat oven to 350°. In a large skillet over medium-high heat, heat oil. Cook onion until soft, 4 to 5 minutes, then add beef and cook until no longer pink, about 6 minutes. Drain fat, then add beef to a large bowl.Wipe out skillet and add bacon. Cook over medium heat until crispy, 6 minutes, then drain on a paper towel-lined plate. Let cool, then crumble and add to bowl with the beef.Addcream cheese, cheddar, Monterey jack, Worcestershire, and garlic powder to bowland season generously with salt and pepper.Transfer mixture to an ovenproof baking dish or skilletand bake until dip iswarmed through and cheese is golden and bubbly, 12 to 15 minutes. Serve with potato chips.']
# http://www.delish.com/search//cooking/recipe-ideas/a44538/bacon-cheeseburger-dip-recipe/
# Bacon Cheeseburger Dip
# 0hours25mins
# 0hours40mins
# ['1 tbsp.extra-virgin olive oil', '1 large onion, chopped', ' 1/2lb.ground beef', '6 slices bacon', '8 oz.cream cheese, softened', ' 3/4c.shredded cheddar', ' 3/4c.shredded Monterey jack', '1 tbsp.Worcestershire sauce', '1 tsp.garlic powder']
# ['Preheat oven to 350°. In a large skillet over medium-high heat, heat oil. Cook onion until soft, 4 to 5 minutes, then add beef and cook until no longer pink, about 6 minutes. Drain fat, then add beef to a large bowl.Wipe out skillet and add bacon. Cook over medium heat until crispy, 6 minutes, then drain on a paper towel-lined plate. Let cool, then crumble and add to bowl with the beef.Addcream cheese, cheddar, Monterey jack, Worcestershire, and garlic powder to bowland season generously with salt and pepper.Transfer mixture to an ovenproof baking dish or skilletand bake until dip iswarmed through and cheese is golden and bubbly, 12 to 15 minutes. Serve with potato chips.']

# %% [markdown]
# L = appended_lists
# recipes = [x for x in L if x is None ]

# %%
import sqlite3

conn = sqlite3.connect('recipedata.db')
cur = conn.cursor()
cur.execute('''CREATE TABLE IF NOT EXISTS Recipes (url TEXT, title TEXT, prep_time TEXT, total_time TEXT, ingredients_list  TEXT,instruction_list TEXT)''')
cur.executemany("INSERT INTO recipes(url, title, prep_time, total_time, ingredients_list,instruction_list) VALUES (?,?)", recipes)
conn.commit()
finally:
    conn.close()
